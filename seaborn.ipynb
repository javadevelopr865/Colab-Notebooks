# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
sns.set_theme()
#sns.set_theme(style= , palette=, axes=)
#sns.set_style("darkgrid")    #whitegrid, dark, white, ticks
sns.reset_defaults()
sns.reset_orig()
